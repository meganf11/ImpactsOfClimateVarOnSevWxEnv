# %%
import pandas as pd
import xarray as xr
import numpy as np
import glob as glob 
import os
import matplotlib.pyplot as plt
import cmocean

##### Region Information
### CONUS
lat_interest = slice(14,64)     ## This is in degrees north for CONUS
lon_interest = slice(230,295)   ### This is in degrees east for CONUS
region_description = 'CONUS'

### ------------------------------------------------------------------------------
mask = xr.open_dataset('/Users/mfranke/Desktop/LandMaskandGlobePlotting/p_cal_cesm2_mask.nc')

# %% [markdown]
# Note:
# - 6hourly to daily data is the 'Daily Average'
# - 6hourly is the 'sub-daily' or the '00 UTC' time, whichever is preferred

# %% [markdown]
# ## Start with the daily mean data:

# %% [markdown]
# #### CAPE 6hourly to daily:

# %%
# hist_file = sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.19*.nc')))
# fut_file =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BSSP370smbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.*.nc')))
# fut_file2 =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.20*.nc')))
# hist_data = xr.open_mfdataset(hist_file).where(mask.LSMASK == 1.0).mcape
# fut_data = xr.open_mfdataset(fut_file).where(mask.LSMASK == 1.0).mcape
# fut_data2 = xr.open_mfdataset(fut_file2).where(mask.LSMASK == 1.0).mcape
# cape_daily_data = xr.concat([hist_data, fut_data2, fut_data], dim = 'time')

# #### Resample to monthly data:
# cape_daily_resamp = cape_daily_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# cape_daily_mamj = cape_daily_resamp.sel(time = cape_daily_resamp.time.dt.month.isin([3,4,5,6]))
# cape_daily_base = cape_daily_mamj.sel(time = slice('1971','2000'))
# cape_daily_climo = cape_daily_base.groupby('time.month').mean('time')
# cape_daily_anoms = cape_daily_mamj.groupby('time.month') - cape_daily_climo
# cape_daily_anom = cape_daily_anoms.groupby('time.year').mean('time')
# cape_daily_anom_ts = cape_daily_anom.sel(lat = lat_small, lon = lon_small).mean(dim = ['lat','lon'])

# %% [markdown]
# #### S06 6hourly to daily:

# %%
# hist_file = sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.S06.19*.nc')))
# fut_file =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BSSP370smbb.f09_g17.LE2-1011.001.cam.h2.S06.*.nc')))
# fut_file2 =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.S06.20*.nc')))
# hist_data = xr.open_mfdataset(hist_file).where(mask.LSMASK == 1.0).S06
# fut_data = xr.open_mfdataset(fut_file).where(mask.LSMASK == 1.0).S06
# fut_data2 = xr.open_mfdataset(fut_file2).where(mask.LSMASK == 1.0).S06
# s06_daily_data = xr.concat([hist_data, fut_data2, fut_data], dim = 'time')

# #### Resample to monthly data:
# s06_daily_resamp = s06_daily_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# s06_daily_mamj = s06_daily_resamp.sel(time = s06_daily_resamp.time.dt.month.isin([3,4,5,6]))
# s06_daily_base = s06_daily_mamj.sel(time = slice('1971','2000'))
# s06_daily_climo = s06_daily_base.groupby('time.month').mean('time')
# s06_daily_anoms = s06_daily_mamj.groupby('time.month') - s06_daily_climo
# s06_daily_anom = s06_daily_anoms.groupby('time.year').mean('time')
# s06_daily_anom_ts = s06_daily_anom.sel(lat = lat_small, lon = lon_small).mean(dim = ['lat','lon'])
# Out:
# /scratch/megan11/anacondaenvironments/stratus/lib/python3.10/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 201 times more chunks
#   return self.array[key]

# %% [markdown]
# #### CIN 6hourly to daily:

# %%
# hist_file = sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.19*.nc')))
# fut_file =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BSSP370smbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.*.nc')))
# fut_file2 =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly_to_daily/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.20*.nc')))
# hist_data = xr.open_mfdataset(hist_file).where(mask.LSMASK == 1.0).mcin
# fut_data = xr.open_mfdataset(fut_file).where(mask.LSMASK == 1.0).mcin
# fut_data2 = xr.open_mfdataset(fut_file2).where(mask.LSMASK == 1.0).mcin
# cin_daily_data = xr.concat([hist_data, fut_data2, fut_data], dim = 'time')

# #### Resample to monthly data:
# cin_daily_resamp = cin_daily_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# cin_daily_mamj = cin_daily_resamp.sel(time = cin_daily_resamp.time.dt.month.isin([3,4,5,6]))
# cin_daily_base = cin_daily_mamj.sel(time = slice('1971','2000'))
# cin_daily_climo = cin_daily_base.groupby('time.month').mean('time')
# cin_daily_anoms = cin_daily_mamj.groupby('time.month') - cin_daily_climo
# cin_daily_anom = cin_daily_anoms.groupby('time.year').mean('time')
# cin_daily_anom_ts = cin_daily_anom.sel(lat = lat_small, lon = lon_small).mean(dim = ['lat','lon'])
# Out:
# /scratch/megan11/anacondaenvironments/stratus/lib/python3.10/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 201 times more chunks
#   return self.array[key]

# %% [markdown]
# #### CAPES06 6hourly to daily:

# %%
# ### Compute CAPES06 from CAPE and S06 datasets:
# capes06_daily_data = cape_daily_resamp * s06_daily_resamp

# #### Resample to monthly data:
# capes06_daily_resamp = capes06_daily_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# capes06_daily_mamj = capes06_daily_resamp.sel(time = capes06_daily_resamp.time.dt.month.isin([3,4,5,6]))
# capes06_daily_base = capes06_daily_mamj.sel(time = slice('1971','2000'))
# capes06_daily_climo = capes06_daily_base.groupby('time.month').mean('time')
# capes06_daily_anoms = capes06_daily_mamj.groupby('time.month') - capes06_daily_climo
# capes06_daily_anom = capes06_daily_anoms.groupby('time.year').mean('time')
# capes06_daily_anom_ts = capes06_daily_anom.sel(lat = lat_small, lon = lon_small).mean(dim = ['lat','lon'])
# Out:
# /scratch/megan11/anacondaenvironments/stratus/lib/python3.10/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 201 times more chunks
#   return self.array[key]

# %%
# capes06_daily_anom_ts.to_netcdf('capes06_DailyMeanTS_Frontiers_031924_maskedOcean.nc')
# cin_daily_anom_ts.to_netcdf('cin_DailyMeanTS_Frontiers_031924_maskedOcean.nc')
# s06_daily_anom_ts.to_netcdf('s06_DailyMeanTS_Frontiers_031924_maskedOcean.nc')
# cape_daily_anom_ts.to_netcdf('cape_DailyMeanTS_Frontiers_031924_maskedOcean.nc')

# %% [markdown]
# ## Now load in the 4x-daily data:

# %% [markdown]
# #### CAPE 4x-Daily:

# %%
# ######### Grab and open the datasets for S06:
# cape_hist_file = sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.*.nc')))
# cape_fut_file =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly/b.e21.BSSP370smbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.*.nc')))

# #### Mask the ocean data:
# cape_hist_data = xr.open_mfdataset(cape_hist_file).where(mask.LSMASK == 1.0).mcape
# cape_fut_data = xr.open_mfdataset(cape_fut_file).where(mask.LSMASK == 1.0).mcape
# cape_4x_data = xr.concat([cape_hist_data, cape_fut_data], dim = 'time')

# #### Resample to monthly data:
# cape_4x_resamp = cape_4x_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# cape_4x_mamj = cape_4x_resamp.sel(time = cape_4x_resamp.time.dt.month.isin([3,4,5,6]))
# cape_4x_base = cape_4x_mamj.sel(time = slice('1971','2000'))
# cape_4x_climo = cape_4x_base.groupby('time.month').mean('time')
# cape_4x_anoms = cape_4x_mamj.groupby('time.month') - cape_4x_climo
# cape_4x_anom = cape_4x_anoms.groupby('time.year').mean('time')
# cape_4x_anom_ts = cape_4x_anom.sel(lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
# Out:
# /scratch/megan11/anacondaenvironments/stratus/lib/python3.10/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 251 times more chunks
#   return self.array[key]

# %% [markdown]
# #### S06 4x-Daily:

# %%
# ######### Grab and open the datasets for S06:
# s06_hist_file = sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.S06.*.nc')))
# s06_fut_file =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly/b.e21.BSSP370smbb.f09_g17.LE2-1011.001.cam.h2.S06.*.nc')))

# #### Mask the ocean data:
# s06_hist_data = xr.open_mfdataset(s06_hist_file).where(mask.LSMASK == 1.0).S06
# s06_fut_data = xr.open_mfdataset(s06_fut_file).where(mask.LSMASK == 1.0).S06
# s06_4x_data = xr.concat([s06_hist_data, s06_fut_data], dim = 'time')

# #### Resample to monthly data:
# s06_4x_resamp = s06_4x_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# s06_4x_mamj = s06_4x_resamp.sel(time = s06_4x_resamp.time.dt.month.isin([3,4,5,6]))
# s06_4x_base = s06_4x_mamj.sel(time = slice('1971','2000'))
# s06_4x_climo = s06_4x_base.groupby('time.month').mean('time')
# s06_4x_anoms = s06_4x_mamj.groupby('time.month') - s06_4x_climo
# s06_4x_anom = s06_4x_anoms.groupby('time.year').mean('time')
# s06_4x_anom_ts = s06_4x_anom.sel(lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
# Out:
# /scratch/megan11/anacondaenvironments/stratus/lib/python3.10/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 251 times more chunks
#   return self.array[key]

# %% [markdown]
# #### CIN 4x-Daily:

# %%
# ######### Grab and open the datasets for S06:
# cin_hist_file = sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly/b.e21.BHISTsmbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.*.nc')))
# cin_fut_file =sorted(glob.glob(('/hurrell-scratch/mfranke/CESM2LE/Data/6hourly/b.e21.BSSP370smbb.f09_g17.LE2-1011.001.cam.h2.wrf_cape_2d.*.nc')))

# #### Mask the ocean data:
# cin_hist_data = xr.open_mfdataset(cin_hist_file).where(mask.LSMASK == 1.0).mcin
# cin_fut_data = xr.open_mfdataset(cin_fut_file).where(mask.LSMASK == 1.0).mcin
# cin_4x_data = xr.concat([cin_hist_data, cin_fut_data], dim = 'time')

# #### Resample to monthly data:
# cin_4x_resamp = cin_4x_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# cin_4x_mamj = cin_4x_resamp.sel(time = cin_4x_resamp.time.dt.month.isin([3,4,5,6]))
# cin_4x_base = cin_4x_mamj.sel(time = slice('1971','2000'))
# cin_4x_climo = cin_4x_base.groupby('time.month').mean('time')
# cin_4x_anoms = cin_4x_mamj.groupby('time.month') - cin_4x_climo
# cin_4x_anom = cin_4x_anoms.groupby('time.year').mean('time')
# cin_4x_anom_ts = cin_4x_anom.sel(lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
# Out:
# /scratch/megan11/anacondaenvironments/stratus/lib/python3.10/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 251 times more chunks
#   return self.array[key]

# %% [markdown]
# #### CAPES06 4x-Daily:

# %%
# ### Compute CAPES06 from CAPE and S06 datasets:
# capes06_4x_data = cape_4x_resamp * s06_4x_resamp

# #### Resample to monthly data:
# capes06_4x_resamp = capes06_4x_data.resample(time = 'MS').mean(dim = 'time')

# ### Compute the anomalies: 
# capes06_4x_mamj = capes06_4x_resamp.sel(time = capes06_4x_resamp.time.dt.month.isin([3,4,5,6]))
# capes06_4x_base = capes06_4x_mamj.sel(time = slice('1971','2000'))
# capes06_4x_climo = capes06_4x_base.groupby('time.month').mean('time')
# capes06_4x_anoms = capes06_4x_mamj.groupby('time.month') - capes06_4x_climo
# capes06_4x_anom = capes06_4x_anoms.groupby('time.year').mean('time')
# capes06_4x_anom_ts = capes06_4x_anom.sel(lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
# Out:
# /scratch/megan11/anacondaenvironments/stratus/lib/python3.10/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing with an out-of-order index is generating 251 times more chunks
#   return self.array[key]

# %%
# capes06_4x_anom_ts.to_netcdf('capes06_4xDailyTS_Frontiers_031924.nc')
# cin_4x_anom_ts.to_netcdf('cin_4xDailyTS_Frontiers_031924.nc')
# s06_4x_anom_ts.to_netcdf('s06_4xDailyTS_Frontiers_031924.nc')
# cape_4x_anom_ts.to_netcdf('cape_4xDailyTS_Frontiers_031924.nc')

# %% [markdown]
# # Re-Open Data and Plot:

# %%
### CONUS
lat_interest = slice(14,64)     ## This is in degrees north for CONUS
lon_interest = slice(230,295)   ### This is in degrees east for CONUS
region_description = 'CONUS'

# %% [markdown]
# ### Daily Data

# %%
### Full CONUS
cape_daily_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/cape_DailyMeanTS_FullCONUS_Frontiers_031924_maskedOcean.nc').mcape.sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
capes06_daily_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/capes06_DailyMeanTS_FullCONUS_Frontiers_031924_maskedOcean.nc').sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])['__xarray_dataarray_variable__']
s06_daily_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/s06_DailyMeanTS_FullCONUS_Frontiers_031924_maskedOcean.nc').S06.sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
cin_daily_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/cin_DailyMeanTS_FullCONUS_Frontiers_031924_maskedOcean.nc').mcin.sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon']) * (-1)

# %% [markdown]
# ### 4x-Daily Data

# %%
### Full CONUS
cape_4x_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/cape_4xDailyTS_conus_Frontiers_031924.nc').mcape.sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
capes06_4x_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/capes06_4xDailyTS_conus_Frontiers_031924.nc').sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])['__xarray_dataarray_variable__']
s06_4x_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/s06_4xDailyTS_conus_Frontiers_031924.nc').S06.sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon'])
cin_4x_anom_ts = xr.open_dataset('/Users/mfranke/Desktop/MSPaper/newTS/Frontiers/Plots/cin_4xDailyTS_conus_Frontiers_031924.nc').mcin.sel(year = slice('1900',None), lat = lat_interest, lon = lon_interest).mean(dim = ['lat','lon']) * (-1)
# Out:
# The region is roughly the CONUS

# %% [markdown]
# ### Plotting:

# %%
import proplot as pplt
fig, axs = pplt.subplots(ncols = 2, nrows = 2, figsize = (15,7), sharey = False)
ax1, ax2, ax3, ax4 = axs 
years = ['1900','1925','1950','1975','2000','2025','2050','2075','2100']
fontweight = 'bold'
# fontweight = None

fig.suptitle('Time Series and Correlations Coefficients of MAMJ Anomalies \nFrom 00Z Data and Daily Mean Data Over ' + region_description, fontsize = 18)
ax1.set_title('CAPE', fontsize = 16, fontweight = fontweight)
ax2.set_title('S06', fontsize = 16, fontweight = fontweight)
ax3.set_title('CAPES06', fontsize = 16, fontweight = fontweight)
ax4.set_title('CIN', fontsize = 16, fontweight = fontweight )

ax1.plot(cape_daily_anom_ts.year.values, cape_daily_anom_ts.values, color = 'blue', label = 'Daily', linestyle = None, linewidth = .75)
ax2.plot(s06_daily_anom_ts.year.values, s06_daily_anom_ts.values, color = 'blue', label = 'Daily', linestyle = None, linewidth = .75)
ax3.plot(capes06_daily_anom_ts.year.values, capes06_daily_anom_ts.values, color = 'blue', label = 'Daily', linestyle = None, linewidth = .75)
ax4.plot(cin_daily_anom_ts.year.values, cin_daily_anom_ts.values, color = 'blue', label = 'Daily', linestyle = None, linewidth = .75)


ax1.plot(cape_4x_anom_ts.year.values, cape_4x_anom_ts.values, color = 'red', label = ' 4x-Daily', linestyle = '--', linewidth = .75)
ax2.plot(s06_4x_anom_ts.year.values, s06_4x_anom_ts.values, color = 'red', label = '4x-Daily', linestyle = '--', linewidth = .75)
ax3.plot(capes06_4x_anom_ts.year.values, capes06_4x_anom_ts.values, color = 'red', label = '4x-Daily', linestyle = '--', linewidth = .75)
ax4.plot(cin_4x_anom_ts.year.values, cin_4x_anom_ts.values, color = 'red', label = '4x-Daily', linestyle = '--', linewidth = .75)

axs.set_xlabel('Year', fontsize = 16, fontweight = fontweight)
ax1.set_ylabel('J/kg', fontsize = 16, fontweight = fontweight)
ax2.set_ylabel('m/s', fontsize = 16, fontweight = fontweight)
ax4.set_ylabel('J/kg', fontsize = 16, fontweight = fontweight)
ax3.set_ylabel('m$^{3}$/s$^{3}$', fontsize = 16, fontweight = fontweight)
ax1.set_xticklabels(years, fontsize = 14)
ax2.set_xticklabels(years, fontsize = 14)
ax3.set_xticklabels(years, fontsize = 14)
ax4.set_xticklabels(years, fontsize = 14)

values_1 = ['-100','-50','0','50','100','150','200','250']
values_2 = ['-1.5','-1.25','-1','-.75','-.5','-.25','0','.25','.5','.75']
values_3 = ['-1500','-1000','-500','0','500','1000','1500','2000','2500','3000']
values_4 = ['-17.5','-15','-12.5','-10','-7.5','-5','-2.5','0','2.5','5']

ax1.set_yticklabels(values_1, fontsize = 14)
ax2.set_yticklabels(values_2, fontsize = 14)
ax3.set_yticklabels(values_3, fontsize = 14)
ax4.set_yticklabels(values_4, fontsize = 14)

ax1.legend(ncol=2, loc = 'upper left', prop={'size': 13})
ax2.legend(ncol=2, loc = 'lower left', prop={'size': 13})
ax3.legend(ncol=2, loc = 'upper left', prop={'size': 13})
ax4.legend(ncol=2, loc = 'lower left', prop={'size': 13})

ax4.annotate(text = '00 UTC & Daily: r = '+ str(cinr), xycoords = 'data', xy = (1910,-8), color = 'k', fontsize = 16)   #### The xy point is where the text is located via 


ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
# plt.show()
# plt.savefig('4panel_00zDailyMean_TS_Rval_Frontiers_4xdaily_daily_WY.jpg', dpi = 500)
# Out:
# /var/folders/0b/0c7lc1j513d2chdmnn82h9fr0002ht/T/ipykernel_40495/3949742967.py:31: ProplotWarning: Calling arbitrary axes methods from SubplotGrid was deprecated in v0.8 and will be removed in a future release. Please index the grid or loop over the grid instead.
#   axs.set_xlabel('Year', fontsize = 16, fontweight = fontweight)
# /var/folders/0b/0c7lc1j513d2chdmnn82h9fr0002ht/T/ipykernel_40495/3949742967.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(years, fontsize = 14)
# /var/folders/0b/0c7lc1j513d2chdmnn82h9fr0002ht/T/ipykernel_40495/3949742967.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(years, fontsize = 14)
# /var/folders/0b/0c7lc1j513d2chdmnn82h9fr0002ht/T/ipykernel_40495/3949742967.py:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(years, fontsize = 14)
# ...

# %% [markdown]
# ### Correlation Values:

# %%
### ----------------------------- CAPE
xcape_sday = cape_4x_anom_ts.values 
ycape_sday = cape_daily_anom_ts.values
xxcape_sday = xr.DataArray(xcape_sday)
yycape_sday = xr.DataArray(ycape_sday)
cape_rsday = xr.corr(xxcape_sday, yycape_sday)
print('cape_r value between sub-daily and daily data = ' + str(cape_rsday))
caper_sday = 0.99
# Out:
# cape_r value between sub-daily and daily data = <xarray.DataArray ()>
# array(0.9981277)

# %%
### ----------------------------- s06
xs06_sday = s06_4x_anom_ts.values 
ys06_sday = s06_daily_anom_ts.values
xxs06_sday = xr.DataArray(xs06_sday)
yys06_sday = xr.DataArray(ys06_sday)
s06_rsday = xr.corr(xxs06_sday, yys06_sday)
print('s06_r value between sub-daily and daily data = ' + str(s06_rsday))

s06r_sday = 0.99
# Out:
# s06_r value between sub-daily and daily data = <xarray.DataArray ()>
# array(0.99932968)

# %%
### ----------------------------- CAPES06
xcapes06_sday = capes06_4x_anom_ts.values 
ycapes06_sday = capes06_daily_anom_ts.values
xxcapes06_sday = xr.DataArray(xcapes06_sday)
yycapes06_sday = xr.DataArray(ycapes06_sday)
capes06_rsday = xr.corr(xxcapes06_sday, yycapes06_sday)
print('capes06_r value between sub-daily and daily data = ' + str(capes06_rsday))

capes06r_sday = 0.98
# Out:
# capes06_r value between sub-daily and daily data = <xarray.DataArray ()>
# array(0.99654825)

# %%
### ----------------------------- CIN
xcin_sday = cin_4x_anom_ts.values 
ycin_sday = cin_daily_anom_ts.values
xxcin_sday = xr.DataArray(xcin_sday)
yycin_sday = xr.DataArray(ycin_sday)
cin_rsday = xr.corr(xxcin_sday, yycin_sday)
print('cin_r value between sub-daily and daily data = ' + str(cin_rsday))

cinr_sday = 0.94
# Out:
# cin_r value between sub-daily and daily data = <xarray.DataArray ()>
# array(0.97573075)
